# %% [markdown]
# # Graduate Project of CNN Regression version 4.0 - Simple CNN

# %% [markdown]
# ## Initialize machine learning library

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
print(torch.__version__)
# Out:
# 2.6.0+cpu

# %% [markdown]
# ### Set computing device as CPU

# %%
device = torch.device("cpu")
print(f"Using Device: {device}")
# Out:
# Using Device: cpu

# %% [markdown]
# ## Data load in and pre-processing

# %%
features = pd.read_csv("/home/seb/Project/BEng-Graduate/data/data.csv", header=None)
features = features.transpose()
# features = data.values.T.astype(np.float32)
features.head()
# Out:
#     0      1      2           3          4       5       6       7       8    \
# 0  70.0  200.0  300.0   28.801196  81.105366  6125.0  5690.0  6560.0   870.0
# 1  70.0  200.0  400.0    2.517709  47.612011  3860.0  3840.0  3880.0    40.0
# 2  70.0  200.0  500.0    3.068820  63.245190  3945.0  3920.0  3970.0    50.0
# 3  70.0  200.0  600.0    5.874144  55.115136  4050.0  4000.0  4100.0   100.0
# 4  70.0  200.0  700.0 -123.202804  67.654798  3635.0  4160.0  3110.0 -1050.0
#
#           9    ...         500         501         502         503  \
# 0 -120.782809  ... -118.949780 -118.499691 -118.020283 -117.503018
# 1 -121.070769  ... -116.630247 -116.579676 -116.529680 -116.480227
# 2 -121.322709  ... -113.516857 -113.319928 -113.096880 -112.840765
# 3 -121.477196  ... -108.600004 -104.475919  -92.225585 -111.170745
# 4 -121.156614  ... -116.668022 -116.650467 -116.633328 -116.616634
#
#           504         505         506         507         508         509
# 0 -116.936596 -116.305609 -115.588315 -114.752730 -113.749309 -112.495888
# 1 -116.431285 -116.382825 -116.334820 -116.287244 -116.240073 -116.193283
# 2 -112.541882 -112.186250 -111.752916 -111.208943 -110.499310 -109.524470
# 3 -123.172305 -140.835187 -127.837068 -124.087345 -122.231465 -121.097501
# 4 -116.600387 -116.584503 -116.569146 -116.554043 -116.539304 -116.524892
#
# [5 rows x 510 columns]

# %% [markdown]
# Check data shape

# %%
print("data dimension:", features.shape)
# Out:
# data dimension: (392, 510)

# %% [markdown]
# ### Draw original feature-describing histograms

# %%
fea = features.iloc[:, :9]
fea.hist(bins=50, figsize=(10,10))
plt.show()

# %% [markdown]
# ### Set label and transform it into a nparray

# %%
labels = np.array(features.iloc[:,9:])
features = np.array(features.iloc[:, :9])
features.shape
# Out:
# (392, 9)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Show the variation of respective features

# %%
plt.figure(figsize=(16,15))
color = ['b', 'g', '#7f7f7f', 'r', 'c', 'm', 'y', 'k', '#FFA500']
for i in range(9):
  plt.subplot(9,1, i+1)
  a, = plt.plot(features[:,i],color= color[i])
  plt.title(i)

plt.show()

# %% [markdown]
# ### Data standardization using sklearn

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
input_features = preprocessing.StandardScaler().fit_transform(features)
input_labels = preprocessing.StandardScaler().fit_transform(labels)
input_features[0]
# Out:
# array([-1.5       , -1.5       , -1.52752523,  0.47353794,  0.91441986,
#         2.55646587,  2.22862805,  2.44093019,  1.07199055])

# %% [markdown]
# ### Show histograms of standardized-features

# %%
plt.hist(input_features, bins=50)
plt.show()

# %% [markdown]
# ## Split data set into training and validating

# %%
x_train, x_val, y_train, y_val = train_test_split(input_features, input_labels, train_size = 0.8, shuffle = True, random_state = 2019)
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).reshape(-1, 9, 1)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)

x_val_tensor = torch.tensor(x_val, dtype=torch.float32).reshape(-1, 9, 1)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

# %% [markdown]
# check set tpye

# %%
print(type(x_train))
print(type(x_train_tensor))
# Out:
# <class 'numpy.ndarray'>
# <class 'torch.Tensor'>

# %% [markdown]
# ## Constract Convolutional Neural Network

# %% [markdown]
# ### Import torch libraries

# %%
import torch.nn as nn
from torch.nn import Conv1d 
from torch.nn import MaxPool1d 
from torch.nn import Flatten 
from torch.nn import AvgPool1d
from torch.nn import BatchNorm1d
from torch.nn import Linear 
from torch.utils.data import DataLoader, TensorDataset 
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# ### Define Hyper-parameters and set dataloader

# %%
input_size = 9
output_size = 501
num_epochs = 100
batch_size = 32

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ### Set up CNN module

# %%
class CNNRegressor(nn.Module):
    def __init__(self, inputs, outputs):
        super(CNNRegressor, self).__init__()
        self.inputs = inputs
        self.outputs = outputs

        # Convolution Sequence 1
        self.conv1 = nn.Sequential(
            nn.Conv1d(
                inputs, 
                16, 
                kernel_size = 3,
                padding = 1
            ),
            nn.ReLU()
        )

        # Convolution Sequence 2 with Batch Normalization and AP
        self.conv2 = nn.Sequential(
            nn.Conv1d(16, 64, kernel_size = 3, padding = 1),
            nn.BatchNorm1d(num_features = 64),
            nn.ReLU()
        )

        # Convolution Sequence 3 with 3 convolutional layers
        self.conv3 = nn.Sequential(
            nn.Conv1d(64, 128, kernel_size = 3, padding = 1),
            nn.BatchNorm1d(num_features = 128),
            nn.ReLU(),
            nn.Conv1d(128, 256, kernel_size = 3, padding = 1),
            nn.BatchNorm1d(num_features = 256),
            nn.ReLU()
        )

        # Convolution Sequence 4 with flatten and FC layers
        self.conv4 = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256, 512),
            nn.ReLU()
        )

        self.out = nn.Linear(512, outputs)

    # Forward function
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # print("Before Flatten: ", x.shape)
        x = self.conv4(x)
        # print("After Flatten: ", x.shape)
        x = self.out(x)
        return x

# %% [markdown]
# ### Training CNN model

# %%
# Instantiation
model = CNNRegressor(input_size, output_size)

# Loss function
criterion = nn.MSELoss()

# Optimizer
optimizer = optim.Adam(model.parameters(), lr = 0.01)
# optimizer = SGD(model.parameters(), lr = 1e-7)
# optimizer = Adagrad(model.parameters(), lr= 1e-5)
# optimizer = Adam(model.parameters(), lr = 1e-6 )
# optimizer = RMSprop(model.parameters(), lr = 1e-6 )

# Looping
for epoch in range(num_epochs):
    # Training mode
    model.train()  
    running_loss = 0.0

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        # Backward
        optimizer.zero_grad()  # Empty grad
        loss.backward()        # Compute grad
        optimizer.step()        # Update parameters

        running_loss += loss.item() # Update loss

    # Computer loss
    avg_train_loss = running_loss / len(train_loader)

    # Computer Val loss
    model.eval()  # Evaluation mode
    val_loss = 0.0
    predictions_list = []
    targets_list = []
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            predictions_list.append(outputs.numpy())
            targets_list.append(targets.numpy())

    predictions = np.concatenate(predictions_list, axis=0)
    targets = np.concatenate(targets_list, axis=0)

    avg_val_loss = val_loss / len(val_loader)

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

print("Training Complete.")
# Out:
# Epoch [1/100], Train Loss: 0.9698, Val Loss: 0.9118
# Epoch [2/100], Train Loss: 0.8922, Val Loss: 0.8503
# Epoch [3/100], Train Loss: 0.8487, Val Loss: 0.7842
# Epoch [4/100], Train Loss: 0.8346, Val Loss: 0.7267
# Epoch [5/100], Train Loss: 0.7478, Val Loss: 0.8519
# Epoch [6/100], Train Loss: 0.7478, Val Loss: 0.7230
# Epoch [7/100], Train Loss: 0.7723, Val Loss: 0.7959
# Epoch [8/100], Train Loss: 0.7402, Val Loss: 0.6402
# Epoch [9/100], Train Loss: 0.6886, Val Loss: 0.6548
# Epoch [10/100], Train Loss: 0.6747, Val Loss: 0.6553
# Epoch [11/100], Train Loss: 0.6621, Val Loss: 0.5953
# Epoch [12/100], Train Loss: 0.6638, Val Loss: 0.5796
# Epoch [13/100], Train Loss: 0.5998, Val Loss: 0.5682
# Epoch [14/100], Train Loss: 0.5590, Val Loss: 0.5533
# Epoch [15/100], Train Loss: 0.5923, Val Loss: 0.5428
# Epoch [16/100], Train Loss: 0.5629, Val Loss: 0.5180
# Epoch [17/100], Train Loss: 0.5441, Val Loss: 0.5092
# Epoch [18/100], Train Loss: 0.5225, Val Loss: 0.4849
# Epoch [19/100], Train Loss: 0.5603, Val Loss: 0.4929
# Epoch [20/100], Train Loss: 0.5313, Val Loss: 0.4803
# Epoch [21/100], Train Loss: 0.5227, Val Loss: 0.4845
# Epoch [22/100], Train Loss: 0.5106, Val Loss: 0.4675
# Epoch [23/100], Train Loss: 0.5607, Val Loss: 0.4789
# Epoch [24/100], Train Loss: 0.5355, Val Loss: 0.4917
# Epoch [25/100], Train Loss: 0.5137, Val Loss: 0.4615
# Epoch [26/100], Train Loss: 0.5024, Val Loss: 0.4957
# Epoch [27/100], Train Loss: 0.5355, Val Loss: 0.5578
# Epoch [28/100], Train Loss: 0.5251, Val Loss: 0.4745
# Epoch [29/100], Train Loss: 0.5212, Val Loss: 0.4660
# Epoch [30/100], Train Loss: 0.5028, Val Loss: 0.4653
# Epoch [31/100], Train Loss: 0.4756, Val Loss: 0.4508
# Epoch [32/100], Train Loss: 0.4793, Val Loss: 0.4561
# Epoch [33/100], Train Loss: 0.4787, Val Loss: 0.4513
# Epoch [34/100], Train Loss: 0.4726, Val Loss: 0.4529
# Epoch [35/100], Train Loss: 0.4859, Val Loss: 0.4647
# Epoch [36/100], Train Loss: 0.4912, Val Loss: 0.4544
# Epoch [37/100], Train Loss: 0.5006, Val Loss: 0.4429
# Epoch [38/100], Train Loss: 0.4820, Val Loss: 0.5314
# Epoch [39/100], Train Loss: 0.5321, Val Loss: 0.4731
# Epoch [40/100], Train Loss: 0.4764, Val Loss: 0.4526
# Epoch [41/100], Train Loss: 0.4820, Val Loss: 0.4634
# Epoch [42/100], Train Loss: 0.4782, Val Loss: 0.4734
# Epoch [43/100], Train Loss: 0.4675, Val Loss: 0.4603
# Epoch [44/100], Train Loss: 0.4664, Val Loss: 0.4643
# Epoch [45/100], Train Loss: 0.4904, Val Loss: 0.4645
# Epoch [46/100], Train Loss: 0.4757, Val Loss: 0.4603
# Epoch [47/100], Train Loss: 0.5127, Val Loss: 0.4958
# Epoch [48/100], Train Loss: 0.5307, Val Loss: 0.4913
# Epoch [49/100], Train Loss: 0.4983, Val Loss: 0.5621
# Epoch [50/100], Train Loss: 0.5129, Val Loss: 0.4789
# Epoch [51/100], Train Loss: 0.4946, Val Loss: 0.4690
# Epoch [52/100], Train Loss: 0.4898, Val Loss: 0.4682
# Epoch [53/100], Train Loss: 0.4882, Val Loss: 0.4520
# Epoch [54/100], Train Loss: 0.4800, Val Loss: 0.4513
# Epoch [55/100], Train Loss: 0.4658, Val Loss: 0.4647
# Epoch [56/100], Train Loss: 0.4571, Val Loss: 0.4429
# Epoch [57/100], Train Loss: 0.4542, Val Loss: 0.4496
# Epoch [58/100], Train Loss: 0.4626, Val Loss: 0.4638
# Epoch [59/100], Train Loss: 0.4655, Val Loss: 0.4717
# Epoch [60/100], Train Loss: 0.4675, Val Loss: 0.4665
# Epoch [61/100], Train Loss: 0.4713, Val Loss: 0.4654
# Epoch [62/100], Train Loss: 0.4632, Val Loss: 0.5041
# Epoch [63/100], Train Loss: 0.4683, Val Loss: 0.4794
# Epoch [64/100], Train Loss: 0.4675, Val Loss: 0.4792
# Epoch [65/100], Train Loss: 0.4627, Val Loss: 0.4588
# Epoch [66/100], Train Loss: 0.4552, Val Loss: 0.4499
# Epoch [67/100], Train Loss: 0.4551, Val Loss: 0.4736
# Epoch [68/100], Train Loss: 0.4462, Val Loss: 0.4688
# Epoch [69/100], Train Loss: 0.4410, Val Loss: 0.4619
# Epoch [70/100], Train Loss: 0.4518, Val Loss: 0.4575
# Epoch [71/100], Train Loss: 0.4639, Val Loss: 0.4997
# Epoch [72/100], Train Loss: 0.4668, Val Loss: 0.4423
# Epoch [73/100], Train Loss: 0.4552, Val Loss: 0.4414
# Epoch [74/100], Train Loss: 0.4514, Val Loss: 0.4679
# Epoch [75/100], Train Loss: 0.4399, Val Loss: 0.4598
# Epoch [76/100], Train Loss: 0.4344, Val Loss: 0.4611
# Epoch [77/100], Train Loss: 0.4601, Val Loss: 0.4641
# Epoch [78/100], Train Loss: 0.4370, Val Loss: 0.4657
# Epoch [79/100], Train Loss: 0.4387, Val Loss: 0.4509
# Epoch [80/100], Train Loss: 0.4454, Val Loss: 0.4605
# Epoch [81/100], Train Loss: 0.4365, Val Loss: 0.4890
# Epoch [82/100], Train Loss: 0.4325, Val Loss: 0.4497
# Epoch [83/100], Train Loss: 0.4569, Val Loss: 0.5011
# Epoch [84/100], Train Loss: 0.4788, Val Loss: 0.5274
# Epoch [85/100], Train Loss: 0.4555, Val Loss: 0.4634
# Epoch [86/100], Train Loss: 0.4451, Val Loss: 0.4577
# Epoch [87/100], Train Loss: 0.4588, Val Loss: 0.4618
# Epoch [88/100], Train Loss: 0.4379, Val Loss: 0.4831
# Epoch [89/100], Train Loss: 0.4586, Val Loss: 0.4811
# Epoch [90/100], Train Loss: 0.4595, Val Loss: 0.4979
# Epoch [91/100], Train Loss: 0.4426, Val Loss: 0.4697
# Epoch [92/100], Train Loss: 0.4391, Val Loss: 0.4621
# Epoch [93/100], Train Loss: 0.4572, Val Loss: 0.4669
# Epoch [94/100], Train Loss: 0.4398, Val Loss: 0.4816
# Epoch [95/100], Train Loss: 0.4365, Val Loss: 0.4668
# Epoch [96/100], Train Loss: 0.4271, Val Loss: 0.4854
# Epoch [97/100], Train Loss: 0.4290, Val Loss: 0.4533
# Epoch [98/100], Train Loss: 0.4287, Val Loss: 0.4665
# Epoch [99/100], Train Loss: 0.4257, Val Loss: 0.4767
# Epoch [100/100], Train Loss: 0.4244, Val Loss: 0.4708
# Training Complete.

# %% [markdown]
# ### Compare predictions to actural values

# %%
# Compare actural values with prediction
plt.figure(figsize = (10, 6))
plt.scatter(targets, predictions, alpha=0.5)
plt.plot([targets.max(), targets.min()], [targets.max(), targets.min()], 'r--', lw=2)

# Set graph config
plt.xlabel('Actural'); plt.ylabel('Prediction'); plt.title('Prediction vs Actural')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(predictions, targets)
r2 = r2_score(predictions, targets)

print("MSE: ", mse)
print("R^2 :", r2)
# Out:
# MSE:  0.46031854
# R^2 : -1.1131367683410645
