# %% [markdown]
# # Grad Project with Transfer Learning - version 6.0

# %% [markdown]
# ## Preparations

# %% [markdown]
# ### Import data science and machine learning libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx

import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
# %matplotlib inline
print(torch.__version__)
# Out:
# 2.6.0+cpu

# %% [markdown]
# ### Set computing device as CPU

# %%
device = torch.device("cpu")
print(f"Using Device: {device}")
# Out:
# Using Device: cpu

# %% [markdown]
# ## Data load in and pre-processing

# %%
features = pd.read_csv("/home/sebastian/project/Regression-prediction-of-large-labels-based-on-small-features/data/data.csv", header=None)
features = features.transpose()
features.head()
# Out:
#     0      1      2          3          4       5       6       7      8    \
# 0  70.0  200.0  300.0  28.801196  81.105366  6125.0  5690.0  6560.0  870.0
# 1  70.0  200.0  400.0   2.517709  47.612011  3860.0  3840.0  3880.0   40.0
# 2  70.0  200.0  500.0   3.068820  63.245190  3945.0  3920.0  3970.0   50.0
# 3  70.0  200.0  600.0   5.874144  55.115136  4050.0  4000.0  4100.0  100.0
# 4  70.0  200.0  800.0  28.796385  82.338597  3380.0  3140.0  3620.0  480.0
#
#           9    ...         500         501         502         503  \
# 0 -120.782809  ... -118.949780 -118.499691 -118.020283 -117.503018
# 1 -121.070769  ... -116.630247 -116.579676 -116.529680 -116.480227
# 2 -121.322709  ... -113.516857 -113.319928 -113.096880 -112.840765
# 3 -121.477196  ... -108.600004 -104.475919  -92.225585 -111.170745
# 4 -119.715437  ... -116.835297 -116.822124 -116.809338 -116.796971
#
#           504         505         506         507         508         509
# 0 -116.936596 -116.305609 -115.588315 -114.752730 -113.749309 -112.495888
# 1 -116.431285 -116.382825 -116.334820 -116.287244 -116.240073 -116.193283
# 2 -112.541882 -112.186250 -111.752916 -111.208943 -110.499310 -109.524470
# 3 -123.172305 -140.835187 -127.837068 -124.087345 -122.231465 -121.097501
# 4 -116.785052 -116.773610 -116.762669 -116.752250 -116.742365 -116.733019
#
# [5 rows x 510 columns]

# %%
print("data dimension:", features.shape)
# Out:
# data dimension: (324, 510)

# %% [markdown]
# ### Draw original feature-describing histograms

# %%
fea = features.iloc[:, :9]
fea.hist(bins=50, figsize=(10,10))
plt.show()

# %% [markdown]
# ### Set label and transform it into a nparray

# %%
labels = np.array(features.iloc[:,9:])
features = np.array(features.iloc[:, 1:9])
features.shape
# Out:
# (324, 8)

# %% [markdown]
# ### Data standardization using sklearn

# %%
input_features = preprocessing.MinMaxScaler().fit_transform(features)
input_labels = preprocessing.MinMaxScaler().fit_transform(labels)
input_features[0]
# Out:
# array([0.        , 0.        , 0.9330703 , 0.89536728, 0.94127243,
#        0.94055944, 0.93975904, 0.95454545])

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Normalized Data Describing

# %%
x = pd.DataFrame(input_features[:, 0:8])
y = pd.DataFrame(input_labels)

# %% [markdown]
# ### Show labels distribution

# %% [markdown]
# ### Test features correlations

# %%
corr_matrix = x.corr()
plt.figure(figsize = (10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('features corr heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Delete redundant features

# %%
x_reduced = x.drop(columns=[3, 5, 6, 7])
corr_matrix = x_reduced.corr()
plt.figure(figsize = (10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('features corr heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Show histograms of standardized-features

# %%
features_reduced = np.delete(input_features, [3, 5, 6, 7], axis=1)
plt.hist(features_reduced, bins=50)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
for i in range(4):
    sns.kdeplot(features_reduced[:, i], label=f"Feature {i+1}")
plt.legend()
plt.title("Feature Distributions")
plt.show()

# %%
from scipy.stats import ks_2samp

N_outputs = input_labels.shape[1] 
print(N_outputs)

ks_matrix = np.zeros((N_outputs, N_outputs))

for i in range(N_outputs):
    for j in range(i + 1, N_outputs):  
        ks_stat, _ = ks_2samp(input_labels[:, i], input_labels[:, j])
        ks_matrix[i, j] = ks_stat
        ks_matrix[j, i] = ks_stat  

plt.figure(figsize=(12, 10))
sns.heatmap(ks_matrix, cmap="coolwarm", xticklabels=50, yticklabels=50)  # 50个tick间隔
plt.title("K-S Test Heatmap for 501 Outputs")
plt.xlabel("Output Variables")
plt.ylabel("Output Variables")
plt.show()
# Out:
# 501

# %% [markdown]
# ## Split data set into training and validating

# %%
x_train, x_val, y_train, y_val = train_test_split(features_reduced, input_labels, train_size = 0.8, shuffle = True, random_state = 2019)
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).reshape(-1, 1, 4)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)

x_val_tensor = torch.tensor(x_val, dtype=torch.float32).reshape(-1, 1, 4)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Set up XGBoost Regression model

# %%
xgbr = XGBRegressor(
    objective = "reg:squarederror", 
    n_estimators = 300, 
    max_depth = 8, 
    learning_rate = 0.01,
    subsample = 0.7,
    colsample_bytree = 1.0
)

# %%
xgbr.fit(x_train, y_train)
xgb_train_pred = xgbr.predict(x_train)
xgb_test_pred = xgbr.predict(x_val)
